# %% [markdown]
# <a href="https://colab.research.google.com/github/franmaio/PrimeraEntrega.Maio/blob/main/PrimeraEntrega_Maio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   PRIMERA ENTRAGA DE PROYECTO FINAL - CATALOGO DE VIDEOJUEGOS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 1) - ABSTRACT
#
# El presente Dataset proporciona información completa de videojuegos, teniendo en cuenta ventas, valoraciones, calidad Grafica, Innovación, etc. los cual nos permitirá tener un análisis detallado de esta industria. En nuestro caso y para el analisis del proyecto se abordara un problema predictivo de Ventas de Videojuegos que pueda estimar la cantidad de ventas a futuro en función de las carácterísticas de los Titulos.
#
# Se trabajará con un modelo de regresión en el cual para nuestro caso la Variable Objetivo será la Cantidad de ventas (número de unidades vendidas).
#
#
# 2) MOTIVACION
#
# La motivación subyacente para analizar este conjunto de datos de videojuegos es poder detectar los factores que impulsan el éxito en la industria y comprender las distintas dinámicas que influyen en las decisiones de los jugadores, ya sea analizando las calificaciones de los usuarios como asi tambien las características de los titulos. Esto puede proporcionar información valiosa para la toma de decisiones estratégicas.
#
#
# 3) AUDIENCIA
#
# El análisis que se llevará a cabo, está diseñado para beneficiar en primer medida a los Desarrolladores y diseñadores para que estos puedan obtener percepciones sobre las características de titulos que buscan los jugadores. Adicionalmente servirá para que los editores pueden tomar decisiones informadas sobre la inversión y la comercialización.
#
#
# 4) - OBJETIVO Y NIVEL DE APLICACION DEL ANALISIS
#
# Desarrollar un modelo predictivo que pueda estimar la cantidad de ventas de un videojuego en función de características de los mismos como género, plataforma, Innovación, calificación de los usuarios, etc. para de esta manera identificar tendencias de la industria, oportunidades de mercado y prever la demanda de géneros específicos de juegos.
#
# En lo que respecta al Nivel de Análisis el mismo será definido como nivel Estratégico, tal cual se definió en el punto 2 debido a que la información obtenida luego de realizar el análisis servirá para definir el rumbo para los nuevos títulos que se desarrollarán a futuro.
#
#
# 5) - HIPÓTESIS
#
# Las ventas de videojuegos estén directamente relacionadas de forma positiva con la ponderación promedio de los usuarios y la jugabilidad de los titulos. Además, se espera que factores como el género del juego y la fecha de lanzamiento también influyan en las ventas. La hipótesis se basará en la idea de que los juegos mas innovadores, disponibles en varias plataformas tienden a tener un rendimiento superior en términos de cantidad de ventas.
#
#
# 6) - PREGUNTAS
#
# ¿Como afectan las características específicas de un videojuego en las ventas?
#
# ¿Cuales son los titulos que mas se venderan a futuro?
#
# ¿Hay un género en particular, el cual será mas buscado por los usuarios?
#
# ¿Les importa la Calidad Gráfica de los titulos a la hora de elegirlos?
#
# ¿Prefieren títulos mas innovadores antes de preferir mejores gráficos?
#
# ¿La duración de los juegos es determinante a la hora de comprarlos?

# %% [markdown]
# 5) - DICCIONARIO
#
# Plataforma: Plataforma en la que se lanzó el videojuego (por ejemplo, PC, consola, etc).
#
# Género: La categoría del videojuego en términos de género (por ejemplo, acción, aventura, estrategia).
#
# Año: El año en que el videojuego fue lanzado.
#
# Editorial: La empresa o entidad que publicó y distribuyó el videojuego.
#
# Ventas por Región: Ventas del videojuego por regiones geográficas
#
# Valoración Promedio de los Usuarios: La puntuación o calificación promedio otorgada por los usuarios del videojuego.
#
# Duración del Juego: La cantidad promedio de horas que lleva completar el videojuego.
#
# Innovación: Se refiere a la introducción de nuevas ideas, conceptos, mecánicas de juego, tecnologías, o cualquier elemento novedoso que aporte originalidad y valor a la experiencia del jugador.

# %% [markdown]
# 6) - ANALISIS EXPLORATORIO DE DATOS - EDA

# %%
df = pd.read_excel('/content/gdrive/MyDrive/dataset/Catálogo Video Juegos/dataset videojuegos.xlsx')
df
# Out:
#           ID                                             Nombre Plataforma  \
# 0          1                                         Wii Sports        Wii
# 1          2                                  Super Mario Bros.        NES
# 2          3                                     Mario Kart Wii        Wii
# 3          4                                  Wii Sports Resort        Wii
# 4          5                           Pokemon Red/Pokemon Blue         GB
# ...      ...                                                ...        ...
# 16321  16322                      Farming 2017 - The Simulation        PS4
# 16322  16323                                  Rugby Challenge 3       XOne
# 16323  16324  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV
# 16324  16325   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV
# 16325  16326                   Brothers Conflict: Precious Baby        PSV
#
# ...

# %%
df.head() #MOSTRAMOS LAS PRIMERAS 5 FILAS DEL ARCHIVO QUE UTILIZAREMOS
# Out:
#    ID                    Nombre Plataforma   Año        Genero Editorial  \
# 0   1                Wii Sports        Wii  2006        Sports  Nintendo
# 1   2         Super Mario Bros.        NES  1985      Platform  Nintendo
# 2   3            Mario Kart Wii        Wii  2008        Racing  Nintendo
# 3   4         Wii Sports Resort        Wii  2009        Sports  Nintendo
# 4   5  Pokemon Red/Pokemon Blue         GB  1996  Role-Playing  Nintendo
#
#    Ventas NA(Millones)  Ventas EU (Millones)  Ventas JP (Millones)  \
# 0                41.49                 29.02                  3.77
# 1                29.08                  3.58                  6.81
# 2                15.85                 12.88                  3.79
# 3                15.75                 11.01                  3.28
# 4                11.27                  8.89                 10.22
#
#    Ventas Otros (Millones)  Valoracion promedio del usuario  Jugabilidad  \
# ...

# %%
#Reemplazamos espacios en blanco por _

df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#           ID                                             Nombre Plataforma  \
# 0          1                                         Wii Sports        Wii
# 1          2                                  Super Mario Bros.        NES
# 2          3                                     Mario Kart Wii        Wii
# 3          4                                  Wii Sports Resort        Wii
# 4          5                           Pokemon Red/Pokemon Blue         GB
# ...      ...                                                ...        ...
# 16321  16322                      Farming 2017 - The Simulation        PS4
# 16322  16323                                  Rugby Challenge 3       XOne
# 16323  16324  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV
# 16324  16325   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV
# 16325  16326                   Brothers Conflict: Precious Baby        PSV
#
# ...

# %%
#Cambiamos los nombres de las columnas eliminando los paréntesis.

df.rename(columns = {'Ventas_NA(Millones)':'Ventas_NA_Millones','Ventas_EU_(Millones)':'Ventas_EU_Millones','Ventas_JP_(Millones)':'Ventas_JP_Millones','Ventas_Otros_(Millones)':'Ventas_Otros_Millones'}, inplace = True)
df
# Out:
#           ID                                             Nombre Plataforma  \
# 0          1                                         Wii Sports        Wii
# 1          2                                  Super Mario Bros.        NES
# 2          3                                     Mario Kart Wii        Wii
# 3          4                                  Wii Sports Resort        Wii
# 4          5                           Pokemon Red/Pokemon Blue         GB
# ...      ...                                                ...        ...
# 16321  16322                      Farming 2017 - The Simulation        PS4
# 16322  16323                                  Rugby Challenge 3       XOne
# 16323  16324  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV
# 16324  16325   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV
# 16325  16326                   Brothers Conflict: Precious Baby        PSV
#
# ...

# %%
#Buscamos conocer las ventas totales de Juegos por Región.

Ventas_Totales = ['Ventas_EU_Millones','Ventas_NA_Millones','Ventas_JP_Millones','Ventas_Otros_Millones']
df[Ventas_Totales].sum()
# Out:
# Ventas_EU_Millones       2409.12
# Ventas_NA_Millones       4333.16
# Ventas_JP_Millones       1284.31
# Ventas_Otros_Millones     788.99
# dtype: float64

# %%
#Calculamos las ventas totales por Titulo y agregamos una nueva columna con dicha información.

df['Ventas_Totales_Millones'] = df['Ventas_EU_Millones']+df['Ventas_NA_Millones']+df['Ventas_JP_Millones']+df['Ventas_Otros_Millones']
df
# Out:
#           ID                                             Nombre Plataforma  \
# 0          1                                         Wii Sports        Wii
# 1          2                                  Super Mario Bros.        NES
# 2          3                                     Mario Kart Wii        Wii
# 3          4                                  Wii Sports Resort        Wii
# 4          5                           Pokemon Red/Pokemon Blue         GB
# ...      ...                                                ...        ...
# 16321  16322                      Farming 2017 - The Simulation        PS4
# 16322  16323                                  Rugby Challenge 3       XOne
# 16323  16324  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV
# 16324  16325   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV
# 16325  16326                   Brothers Conflict: Precious Baby        PSV
#
# ...

# %%
#Buscamos conocer los distintos tipos de Datos con los que contamos.
df.dtypes
print('/datos para cada variable',df.dtypes)
# Out:
# /datos para cada variable ID                                   int64
# Nombre                              object
# Plataforma                          object
# Año                                  int64
# Genero                              object
# Editorial                           object
# Ventas_NA_Millones                 float64
# Ventas_EU_Millones                 float64
# Ventas_JP_Millones                 float64
# Ventas_Otros_Millones              float64
# Valoracion_promedio_del_usuario      int64
# Jugabilidad                          int64
# Duracion_del_juego                   int64
# Calidad_grafica                     object
# Innovacion                           int64
# Ventas_Totales_Millones            float64
# dtype: object

# %%
# Verificamos si hay nulos
df.isnull().sum()
# Out:
# ID                                  0
# Nombre                              0
# Plataforma                          0
# Año                                 0
# Genero                              0
# Editorial                          36
# Ventas_NA_Millones                  0
# Ventas_EU_Millones                  0
# Ventas_JP_Millones                  0
# Ventas_Otros_Millones               0
# Valoracion_promedio_del_usuario     0
# Jugabilidad                         0
# Duracion_del_juego                  0
# Calidad_grafica                     0
# Innovacion                          0
# Ventas_Totales_Millones             0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# DESCRIBE
#
# Analizamos la media y nos damos cuenta que para el centro de la distribución la Valoracion promedio del usuario, como asi tambien la puntuacion por Innovación estan cercanas a 5, que seria la puntuación media.
# En referencia a la Desviación Estándar (Std): Muestra qué tan dispersos están los datos con respecto a la media. Cuanto mayor sea la desviación estándar, mayor será la dispersión.

# %%
df.describe()
# Out:
#                  ID           Año  Ventas_NA_Millones  Ventas_EU_Millones  \
# count  16290.000000  16290.000000        16290.000000        16290.000000
# mean    8160.853959   2006.404727            0.265646            0.147740
# std     4712.941354      5.831618            0.822457            0.509317
# min        1.000000   1980.000000            0.000000            0.000000
# 25%     4078.250000   2003.000000            0.000000            0.000000
# 50%     8162.500000   2007.000000            0.080000            0.020000
# 75%    12242.750000   2010.000000            0.240000            0.110000
# max    16326.000000   2017.000000           41.490000           29.020000
#
#        Ventas_JP_Millones  Ventas_Otros_Millones  \
# count        16290.000000           16290.000000
# mean             0.078839               0.048428
# std              0.311888               0.190089
# min              0.000000               0.000000
# 25%              0.000000               0.000000
# ...

# %% [markdown]
# HISTOGRAMA - VARIABLES AÑO / CANTIDAD DE TITULOS
#
# En este gráfico podemos ver la cantidad de juegos totales para los distintos grados de Innovacion del los Títulos. Se puede observar que a partir del 1990 comenzo un incremento en la cantidad de titulos ofrecidos, entendemos debido a una mayor demanda por parte de los usuarios, alcanzando su pico maximo en el año 2006.

# %%
mpl.style.use('bmh')
fig, ax = plt.subplots(figsize=(10,6))
ax.hist(x= df.Año , bins=30, density=False, orientation='vertical')
ax.set_xlabel('Año')
ax.set_ylabel('Cantidad de Titulos')
ax.set_title('Cantidad Titulos/Año')
# Out:
# Text(0.5, 1.0, 'Cantidad Titulos/Año')

# %% [markdown]
# GRAFICO BARPLOT - VENTAS TOTALES / AÑO
#
# Para profundizar mas en la información brindada por el histograma anterior, vemos que los titulos mas vendidos a nivel mundial tuvieron su pico en el año 2006.

# %%
mpl.style.use('bmh')
fig, ax = plt.subplots(figsize=(8,4))
Ventas_Totales = df.Ventas_Totales_Millones
ax.bar(df.Año, Ventas_Totales)
ax.set_title('Ventas Totales / Año')
ax.set_ylabel('Ventas Totales')
ax.set_xlabel('Año')
# Out:
# Text(0.5, 0, 'Año')

# %% [markdown]
# COUNTPLOT - VARIABLE GENERO
#
# Dado lo que observamos para el año 2006 pudimos observar que para el año 2006 hubo un pico de ventas, nos gustaría saber de que genero son los juegos ofrecidos en ese año. De esta manera, filtramos solo la cantidad de titulos asociadas a este año distribuidos por Genero.
#
# Como se puede observar los juegos de Action fueron los mas ofrecidos, seguidos de los juegos de Deportes.

# %%
fig, ax = plt.subplots(figsize=(15,5))
df_2006 = df[(df.Año == 2006)]
sns.countplot(df_2006, x = 'Genero')
# Out:
# <Axes: xlabel='Genero', ylabel='count'>

# %% [markdown]
# COUNTPLOT - VARIABLE GENERO - CANTIDAD TOTAL DE TITULOS
#
# En referencia al gráfico anterior corroboramos que los títulos mas buscados son los de accion. Teniendo una preferencia en los usuarios.

# %%
sns.set(rc= {"figure.figsize": (15, 7)})
sns.countplot(df, x = 'Genero')
# Out:
# <Axes: xlabel='Genero', ylabel='count'>

# %% [markdown]
# Ahora queremos conocer la cantidad de ventas asociadas a los distintos generos y graficar las mismas a traves de un Barplot

# %%
ventas_por_genero = df.groupby('Genero')['Ventas_Totales_Millones'].sum()
print(ventas_por_genero)
# Out:
# Genero
# Action          1721.82
# Adventure        234.36
# Fighting         444.08
# Misc             789.28
# Platform         828.80
# Puzzle           241.68
# Racing           726.54
# Role-Playing     923.74
# Shooter         1025.69
# Simulation       389.41
# Sports          1308.84
# Strategy         173.00
# Name: Ventas_Totales_Millones, dtype: float64

# %% [markdown]
# BARPLOT - VARIABLES VENTAS TOTALES / GENERO

# %%
ventas_por_genero.plot(kind='bar', color=['red', 'pink', 'green', 'gray', 'orange'])
plt.title('Ventas Distribuidas por Género para Valorizaciones = 8')
plt.xlabel('Género')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# BARPLOT - VARIABLES VENTAS TOTALES / VALORACION DE USUARIO DE 0 A 10
#
# Podemos observar que los juegos con una valoración de 8 puntos han sido los mas vendidos. Lo cual nos dice que ponderación por encima de 8 no significa que habran mas ventas. Esto nos lleva a la pregunta de ¿Qué generos tenemos correspondientes a ese nivel de ponderación?

# %%
mpl.style.use('bmh')
fig, ax = plt.subplots(figsize=(8,4))
Ventas_Totales = df.Ventas_Totales_Millones
ax.bar(df.Valoracion_promedio_del_usuario, Ventas_Totales)
ax.set_title('Ventas Totales / Valoración del Usuario')
ax.set_ylabel('Ventas Totales')
ax.set_xlabel('Valoracion Promedio del Usuario')
# Out:
# Text(0.5, 0, 'Valoracion Promedio del Usuario')

# %% [markdown]
# COUNTPLOT - JUEGOS CON VALORIZACION PROMEDIO DEL USUARIO = 8 DISTRIBUIDO POR GENERO
#
# Se puede observar en funcion de las ultimas dos ultimas graficas que dentro de los juegos con una puntuación de valoración = 8 los titulos mas ofrecidos son de Deportes / Accion.

# %%
fig, ax = plt.subplots(figsize=(15,5))
df_8 = df[(df.Valoracion_promedio_del_usuario == 8)]
sns.countplot(df_8, x = 'Genero')
# Out:
# <Axes: xlabel='Genero', ylabel='count'>

# %% [markdown]
# BARPLOT - VARIABLES VENTAS TOTALES / JUGABILIDAD DE 75 A 100
#
# Podemos observar que los juegos con una valoración de Jugabilidad de 95 puntos son los mas vendidos.

# %%
mpl.style.use('bmh')
fig, ax = plt.subplots(figsize=(8,4))
Ventas_Totales = df.Ventas_Totales_Millones
ax.bar(df.Jugabilidad, Ventas_Totales)
ax.set_title('Ventas Totales / Jugabilidad')
ax.set_ylabel('Ventas Totales')
ax.set_xlabel('Jugabilidad')
# Out:
# Text(0.5, 0, 'Jugabilidad')

# %% [markdown]
# BARPLOT - VARIABLES VENTAS TOTALES / CALIDAD GRAFICA
#
# Podemos observar que los juegos de Calidad Grafica Media son los mas vendidos por sobre los demas.

# %%
mpl.style.use('bmh')
fig, ax = plt.subplots(figsize=(8,4))
Ventas_Totales = df.Ventas_Totales_Millones
ax.bar(df.Calidad_grafica, Ventas_Totales)
ax.set_title('Ventas Totales / Calidad Grafica')
ax.set_ylabel('Ventas Totales')
ax.set_xlabel('Calidad Grafica')
# Out:
# Text(0.5, 0, 'Calidad Grafica')

# %% [markdown]
# HISTOGRAMA - VARIABLES INNOVACION / CANTIDAD DE TITULOS
#
# Se observa que levemente a medida que aumenta la innovación volcada en los Juegos hay mas cantidad de titulos ofrecidos. Pero como se puede observar la diferencia es reducida, lo cual nos permite inferir que la innovación volcada a los titulos no es determinante.

# %%
mpl.style.use('bmh')
fig, ax = plt.subplots(figsize=(15,5))
ax.hist(x= df.Innovacion , bins=None, density=False, orientation='vertical')
ax.set_xlabel('Innovacion')
ax.set_ylabel('Cantidad de Títulos')
ax.set_title('Cantidad de Títulos / Calidad Gráfica')
# Out:
# Text(0.5, 1.0, 'Cantidad de Títulos / Calidad Gráfica')

# %% [markdown]
# HISTOGRAMA VARIALBES CALIDAD GRAFICA / INNOVACION
#
# Vemos algo similar al grafico anterior pero diferenciando la cantidad de titulos por calidad grafica

# %%
sns.set(rc= {"figure.figsize": (15, 6)})
sns.histplot(data = df, x = "Innovacion", hue = "Calidad_grafica", multiple="stack")
# Out:
# <Axes: xlabel='Innovacion', ylabel='Count'>

# %% [markdown]
# COUNTPLOT - VARIABLE PLATAFORMA
#
# Podemos observar que la Plataforma PS2 y Nintendo DS ofrecen la mayor cantidad de titulos ofrecidos.

# %%
sns.set(rc= {"figure.figsize": (50, 10)})
sns.countplot(df, x = 'Plataforma')
# Out:
# <Axes: xlabel='Plataforma', ylabel='count'>

# %%
# Aplicamos ONE HOT ENCODING a modo de prueba

# %%
df_encoded = pd.get_dummies(df, columns=['Nombre','Plataforma','Genero','Editorial','Calidad_grafica'])
df_encoded
# Out:
#           ID   Año  Ventas_NA_Millones  Ventas_EU_Millones  \
# 0          1  2006               41.49               29.02
# 1          2  1985               29.08                3.58
# 2          3  2008               15.85               12.88
# 3          4  2009               15.75               11.01
# 4          5  1996               11.27                8.89
# ...      ...   ...                 ...                 ...
# 16321  16322  2016                0.00                0.01
# 16322  16323  2016                0.00                0.01
# 16323  16324  2016                0.00                0.00
# 16324  16325  2017                0.00                0.00
# 16325  16326  2017                0.00                0.00
#
#        Ventas_JP_Millones  Ventas_Otros_Millones  \
# 0                    3.77                   8.46
# 1                    6.81                   0.77
# 2                    3.79                   3.31
# 3                    3.28                   2.96
# ...

# %%
df2 = pd.DataFrame(df, columns = ['Año','Innovacion','Jugabilidad','Valoracion_promedio_del_usuario','Ventas_NA_Millones','Ventas_EU_Millones','Ventas_JP_Millones','Ventas_Otros_Millones','Ventas_Totales_Millones','Duracion_del_juego',])
df.target = df['Ventas_Totales_Millones']
X = df[['Año','Innovacion','Jugabilidad','Valoracion_promedio_del_usuario','Ventas_NA_Millones','Ventas_EU_Millones','Ventas_JP_Millones','Ventas_Otros_Millones','Ventas_Totales_Millones','Duracion_del_juego',]]
y = df['Ventas_Totales_Millones']
df2
# Out:
# <ipython-input-19-f9149384f012>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.target = df['Ventas_Totales_Millones']
#         Año  Innovacion  Jugabilidad  Valoracion_promedio_del_usuario  \
# 0      2006           1           95                                8
# 1      1985           5          100                                5
# 2      2008           3           78                               10
# 3      2009           6           82                                4
# 4      1996           6           81                                9
# ...     ...         ...          ...                              ...
# 16321  2016           1           88                                4
# 16322  2016           3           87                                8
# 16323  2016          10           79                                3
# ...

# %% [markdown]
# UTILIZAR LABEL ENCODER PARA CODIFICAR LAS VARIABLES OBJECT

# %%
# Aplicamos LABEL ENCODER para codificar las Variables que no son numericas

from sklearn.preprocessing import LabelEncoder

dfle = pd.DataFrame(df, columns = ['Nombre_LE','Plataforma_LE','Genero_LE','Editorial_LE','Calidad_grafica_LE'])
df[['Nombre', 'Plataforma','Genero','Editorial','Calidad_grafica']] = df[['Nombre', 'Plataforma','Genero','Editorial','Calidad_grafica']].astype(str)

label_encoder = LabelEncoder()

# Aplicar LabelEncoder a toda la columna 'Categoria'
dfle['Nombre_LE'] = label_encoder.fit_transform(df['Nombre'])
dfle['Plataforma_LE'] = label_encoder.fit_transform(df['Plataforma'])
dfle['Genero_LE'] = label_encoder.fit_transform(df['Genero'])
dfle['Editorial_LE'] = label_encoder.fit_transform(df['Editorial'])
dfle['Calidad_grafica_LE'] = label_encoder.fit_transform(df['Calidad_grafica'])
print(dfle)
# Out:
#        Nombre_LE  Plataforma_LE  Genero_LE  Editorial_LE  Calidad_grafica_LE
# 0          10848             26         10           359                   2
# 1           9200             11          4           359                   2
# 2           5492             26          6           359                   0
# 3          10850             26         10           359                   0
# 4           7246              5          7           359                   0
# ...          ...            ...        ...           ...                 ...
# 16321       3004             18          9           523                   2
# 16322       7983             30         10            31                   2
# 16323       1404             20          0           568                   2
# 16324       7097             20          7           445                   1
# 16325       1044             20          0           230                   1
#
# [16290 rows x 5 columns]
# ...

# %%
# Concatenar df2 y dfle por columnas - DE ESTA MANERA UNIFICAMOS TODOS LOS DATOS NUMERICOS DEL DATASET DF2 CON LOS VARIABLES STRING (AHORA CODIFICADAS A NUMEROS MEDIANTE LE) CON EL DATASET DFLE.
# DE ESTA MANERA TENEMOS TODO EL DATASET LISTO PARA PODER APLICAR LOSMETODOS DE FUTURE SELECTION

df2le = pd.concat([df2, dfle], axis=1)
df2le
# Out:
#         Año  Innovacion  Jugabilidad  Valoracion_promedio_del_usuario  \
# 0      2006           1           95                                8
# 1      1985           5          100                                5
# 2      2008           3           78                               10
# 3      2009           6           82                                4
# 4      1996           6           81                                9
# ...     ...         ...          ...                              ...
# 16321  2016           1           88                                4
# 16322  2016           3           87                                8
# 16323  2016          10           79                                3
# 16324  2017           2           80                               10
# 16325  2017           2           82                                8
#
#        Ventas_NA_Millones  Ventas_EU_Millones  Ventas_JP_Millones  \
# ...

# %%
df3 = pd.DataFrame(df2le, columns = ['Nombre_LE','Plataforma_LE','Genero_LE','Editorial_LE','Calidad_grafica_LE','Año','Innovacion','Jugabilidad','Valoracion_promedio_del_usuario','Ventas_NA_Millones','Ventas_EU_Millones','Ventas_JP_Millones','Ventas_Otros_Millones','Ventas_Totales_Millones','Duracion_del_juego',])
df.target = df['Ventas_Totales_Millones']
X = df2le[['Nombre_LE','Plataforma_LE','Genero_LE','Editorial_LE','Calidad_grafica_LE','Año','Innovacion','Jugabilidad','Valoracion_promedio_del_usuario','Ventas_NA_Millones','Ventas_EU_Millones','Ventas_JP_Millones','Ventas_Otros_Millones','Ventas_Totales_Millones','Duracion_del_juego',]]
y = df2le['Ventas_Totales_Millones']
df3
# Out:
#        Nombre_LE  Plataforma_LE  Genero_LE  Editorial_LE  Calidad_grafica_LE  \
# 0          10848             26         10           359                   2
# 1           9200             11          4           359                   2
# 2           5492             26          6           359                   0
# 3          10850             26         10           359                   0
# 4           7246              5          7           359                   0
# ...          ...            ...        ...           ...                 ...
# 16321       3004             18          9           523                   2
# 16322       7983             30         10            31                   2
# 16323       1404             20          0           568                   2
# 16324       7097             20          7           445                   1
# 16325       1044             20          0           230                   1
#
# ...

# %% [markdown]
# FEATURE SELECTION - FOWARD SELECTION
#
# Codificamos las Variables que son Object para poder aplicar los Métodos de Feature Selection.

# %%
import statsmodels.api as sm
def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

# %%
forward_selection(X,y)
# Out:
# <ipython-input-23-66a4d2c172be>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# <ipython-input-23-66a4d2c172be>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# <ipython-input-23-66a4d2c172be>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# <ipython-input-23-66a4d2c172be>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# ...

# %% [markdown]
# Como se puede observar las mejores variables para nuestro analisis son:
#
# -Ventas_JP_Millones
#
# -Ventas_EU_Millones
#
# -Ventas_Otros_Millones
#
# -Ventas_NA_Millones
#
# -Valoracion_promedio_del_usuario
#
# -Nombre_LE
#
# -Ventas_Totales_Millones
#
# -Editorial_LE

# %% [markdown]
# ALGORITMO DE REGRESION LINEAL
#
# Metrica algoritmos de regresion

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
from sklearn.linear_model import LinearRegression
# crear el modelo
lr = LinearRegression()
# Ajustar el modelo con X_train y y_train
lr.fit(X_train,y_train)
# PRedecir con X_test
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'RMSE: {rmse}')

# %% [markdown]
# CONCLUSIONES
#
# MSE / MAE: El valor de MSE/MAE sugiere que las predicciones del modelo son prácticamente idénticas a los valores reales dado el valor que nos esta entregando el analisis.
#
#
# RMSE: Entendemos que RMSE tiene la ventaja de estar en la misma escala que los datos originales, y un valor cercano a cero indica un ajuste preciso del modelo.
#
# En resumen, estos resultados sugieren que tu modelo ha logrado un ajuste casi perfecto a los datos de prueba.
